# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# ## Baseline rule
#
# The baseline score prioritizes pages that are still visible but are becoming stale or losing performance.
#
# The score combines four signals:
#
# - Visibility score (40%)
# - Freshness risk score (30%)
# - Position opportunity score (25%)
# - Depth gap score (5%)
#
# Reason codes produced by the rule:
#
# - stale_visible_page
# - declining_with_demand
# - thin_visible_page
# - page_one_decay_risk
# - low_ctr_visible_page
# - low_engagement_visible_page
# - general_refresh_review
#
# Possible actions:
#
# - refresh
# - refresh_and_review_ctr
# - expand_and_refresh
# - monitor

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
import pandas as pd

queue = pd.read_csv("outputs/refresh_queue.csv")

queue.head(10)

# %%
queue.to_csv("work/outputs/baseline_action_score.csv", index=False)

print(f"Saved {len(queue)} rows to work/outputs/baseline_action_score.csv")

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
top20 = queue.head(20)

for _, row in top20.iterrows():
    print(f"""
Action: {row['action']}
Reason: {row['reason_code']}
Confidence: Medium

Why it is here:
Page has a relatively high baseline score based on visibility, freshness risk, position opportunity, and depth gap.

What would make it wrong:
The page may already have planned updates, seasonal effects, or missing business context that is not captured by the baseline signals.
""")

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# ## Weak picks
#
# Some lower-ranked pages may have temporary traffic changes or incomplete signals, so they should be reviewed before taking action.
#
# ## Leakage check
#
# The baseline rule only uses current page signals.
#
# No future metrics, labels, or outcome-derived fields were used when calculating the score.
#
# No data leakage was introduced.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
